# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load Packages

# %%
import sys
sys.path.append('..')

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
from numpy_fracadf import fracadf
from numpy_fracdiff import fracdiff

# %% [markdown]
# # Load Data

# %%
with np.load('data/demo1.npz') as data:
    X = data['px']

X = X[1:]  # chop 01-Jan

# %% [markdown]
# # Find best fractal order

# %%
n_trunc = 200

# %time d = fracadf(X, n_trunc=n_trunc)

print(d)
# Out:
# CPU times: user 3.01 s, sys: 207 ms, total: 3.22 s
# Wall time: 2.27 s
# [0.42853641 0.38430947 0.23202419 0.16157006]

# %% [markdown]
# # Display results

# %%
for j in range(X.shape[1]):
    z = fracdiff(X[:, j], order=d[j], truncation=n_trunc)
    plt.plot(z[n_trunc:]);
    plt.show();
